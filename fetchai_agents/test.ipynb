# %%
# !pip install --upgrade uagents uagents-core
# Out:
# Requirement already satisfied: uagents in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.23.6)
# Requirement already satisfied: uagents-core in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.4.0)
# Requirement already satisfied: aiohttp<4.0,>=3.8.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from uagents) (3.13.3)
# Requirement already satisfied: cosmpy<0.12.0,>=0.11.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from uagents) (0.11.2)
# Requirement already satisfied: pydantic<3.0,>=2.8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from uagents) (2.12.5)
# Requirement already satisfied: uvicorn<1.0,>=0.30.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from uagents) (0.40.0)
# Requirement already satisfied: bech32<2.0,>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from uagents-core) (1.2.0)
# Requirement already satisfied: ecdsa<1.0,>=0.19.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from uagents-core) (0.19.1)
# Requirement already satisfied: requests<3.0,>=2.32.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from uagents-core) (2.32.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp<4.0,>=3.8.3->uagents) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp<4.0,>=3.8.3->uagents) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp<4.0,>=3.8.3->uagents) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp<4.0,>=3.8.3->uagents) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp<4.0,>=3.8.3->uagents) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp<4.0,>=3.8.3->uagents) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp<4.0,>=3.8.3->uagents) (1.22.0)
# Requirement already satisfied: bcrypt==5.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from cosmpy<0.12.0,>=0.11.0->uagents) (5.0.0)
# Requirement already satisfied: googleapis-common-protos in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from cosmpy<0.12.0,>=0.11.0->uagents) (1.72.0)
# Requirement already satisfied: grpcio in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from cosmpy<0.12.0,>=0.11.0->uagents) (1.78.0)
# Requirement already satisfied: jsonschema<5,>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from cosmpy<0.12.0,>=0.11.0->uagents) (4.26.0)
# Requirement already satisfied: protobuf<6.0dev,>=4.21.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from cosmpy<0.12.0,>=0.11.0->uagents) (5.29.6)
# Requirement already satisfied: pycryptodome<4.0.0,>=3.18.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from cosmpy<0.12.0,>=0.11.0->uagents) (3.23.0)
# Requirement already satisfied: pynacl==1.6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from cosmpy<0.12.0,>=0.11.0->uagents) (1.6.0)
# Requirement already satisfied: python-dateutil in /Users/jedrzejcader/Library/Python/3.12/lib/python/site-packages (from cosmpy<0.12.0,>=0.11.0->uagents) (2.8.2)
# Requirement already satisfied: sortedcontainers==2.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from cosmpy<0.12.0,>=0.11.0->uagents) (2.4.0)
# Requirement already satisfied: virtualenv>=20.26.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from cosmpy<0.12.0,>=0.11.0->uagents) (20.36.1)
# Requirement already satisfied: cffi>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pynacl==1.6.0->cosmpy<0.12.0,>=0.11.0->uagents) (2.0.0)
# Requirement already satisfied: six>=1.9.0 in /Users/jedrzejcader/Library/Python/3.12/lib/python/site-packages (from ecdsa<1.0,>=0.19.0->uagents-core) (1.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic<3.0,>=2.8->uagents) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic<3.0,>=2.8->uagents) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic<3.0,>=2.8->uagents) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic<3.0,>=2.8->uagents) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests<3.0,>=2.32.3->uagents-core) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests<3.0,>=2.32.3->uagents-core) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests<3.0,>=2.32.3->uagents-core) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests<3.0,>=2.32.3->uagents-core) (2026.1.4)
# Requirement already satisfied: click>=7.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from uvicorn<1.0,>=0.30.1->uagents) (8.3.1)
# Requirement already satisfied: h11>=0.8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from uvicorn<1.0,>=0.30.1->uagents) (0.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema<5,>=3.2.0->cosmpy<0.12.0,>=0.11.0->uagents) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema<5,>=3.2.0->cosmpy<0.12.0,>=0.11.0->uagents) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema<5,>=3.2.0->cosmpy<0.12.0,>=0.11.0->uagents) (0.30.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from virtualenv>=20.26.6->cosmpy<0.12.0,>=0.11.0->uagents) (0.4.0)
# Requirement already satisfied: filelock<4,>=3.20.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from virtualenv>=20.26.6->cosmpy<0.12.0,>=0.11.0->uagents) (3.24.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /Users/jedrzejcader/Library/Python/3.12/lib/python/site-packages (from virtualenv>=20.26.6->cosmpy<0.12.0,>=0.11.0->uagents) (3.11.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from cffi>=1.4.1->pynacl==1.6.0->cosmpy<0.12.0,>=0.11.0->uagents) (3.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os
from uagents_core.utils.registration import (
    register_chat_agent,
    RegistrationRequestCredentials,
)

register_chat_agent(
    "Context Understanding",
    "https://agentverse.ai/v1/mailbox/agent1q07cx08f6p39emk4p3g6hwzndmstszkpgzjp3765yjz7prewd2hewxc9es5",
    active=True,
    credentials=RegistrationRequestCredentials(
        agentverse_api_key=os.environ["AGENTVERSE_KEY"],
        agent_seed_phrase=os.environ["AGENT_SEED"],        
    ),
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import os
# ----> 2 from uagents_core.utils.registration import (
#       3     register_chat_agent,
#       4     RegistrationRequestCredentials,
#       5 )
#       7 register_chat_agent(
#       8     "Context Understanding",
#       9     "https://agentverse.ai/v1/mailbox/agent1q07cx08f6p39emk4p3g6hwzndmstszkpgzjp3765yjz7prewd2hewxc9es5",
#    (...)     14     ),
#      15 )
#
# ModuleNotFoundError: No module named 'uagents_core'
